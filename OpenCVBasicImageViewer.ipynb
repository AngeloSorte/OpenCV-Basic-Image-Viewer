# %% [markdown]
# <a href="https://colab.research.google.com/github/AngeloSorte/OpenCV-Basic-Image-Viewer/blob/angelosorte.github.io/OpenCVBasicImageViewer.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Installing packages on Colab
# !pip install opencv-python

# Import
import cv2
import numpy as np
from google.colab.patches import cv2_imshow  # per mostrare immagini su Colab

# Load image
img = cv2.imread('/content/screencapture-viki-videos-1249283v-2025-05-18-23_37_55.png')
cv2_imshow(img)
cv2.waitKey(0)

# Grayscale
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
cv2_imshow(gray)

# Blur
blur = cv2.GaussianBlur(img, (15, 15), 0)
cv2_imshow(blur)

# Edge detection
edges = cv2.Canny(img, 100, 200)
cv2_imshow(edges)

# Face detection
face_cascade = cv2.CascadeClassifier(cv2.data.haarcascades + 'haarcascade_frontalface_default.xml')
faces = face_cascade.detectMultiScale(gray, 1.1, 4)

# Draw rectangles on faces
for (x, y, w, h) in faces:
    cv2.rectangle(img, (x, y), (x+w, y+h), (0, 255, 0), 3)

cv2_imshow(img)

cv2.destroyAllWindows()
# Out:
# ...
# <PIL.Image.Image image mode=RGB size=1920x927>
# <PIL.Image.Image image mode=L size=1920x927>
# <PIL.Image.Image image mode=RGB size=1920x927>
# <PIL.Image.Image image mode=L size=1920x927>
# <PIL.Image.Image image mode=RGB size=1920x927>
